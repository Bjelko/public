# %%
premenne=["DATE_1",
"TIME_1",
"PART",
"PROCESS",
"SAMPLEINFO1",
"SAMPLEINFO2",
"SAMPLEINFO3",
"SAMPLEINFO4",
"SAMPLEINFO5",
"SAMPLEINFO6",
"SAMPLEINFO7",
"SAMPLEINFO8",
"SAMPLEINFO9",
"SAMPLEINFO10",
"SAMPLEINFO11",
"SAMPLEINFO12",
"SAMPLEINFO13",
"SAMPLEINFO14",
"SAMPLEINFO15",
"SAMPLEINFO16",
"CHARACTERISTICLABEL_1",
"CHARACTERISTICTYPE_1",
"VALUE_1",
"CHARACTERISTICLABEL_2",
"CHARACTERISTICTYPE_2",
"VALUE_2",
"CHARACTERISTICLABEL_3",
"CHARACTERISTICTYPE_3",
"VALUE_3",
"CHARACTERISTICLABEL_4",
"CHARACTERISTICTYPE_4",
"VALUE_4",
"CHARACTERISTICLABEL_5",
"CHARACTERISTICTYPE_5",
"VALUE_5",
"CHARACTERISTICLABEL_6",
"CHARACTERISTICTYPE_6",
"VALUE_6",
"CHARACTERISTICLABEL_7",
"CHARACTERISTICTYPE_7",
"VALUE_7",
"CHARACTERISTICLABEL_8",
"CHARACTERISTICTYPE_8",
"VALUE_8",
"CHARACTERISTICLABEL_9",
"CHARACTERISTICTYPE_9",
"VALUE_9",
"CHARACTERISTICLABEL_10",
"CHARACTERISTICTYPE_10",
"VALUE_10",
"data_ready"]

# %%
begin='''<?xml version="1.0" encoding="utf-8"?>
<TcModuleClass xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:noNamespaceSchemaLocation="http://www.beckhoff.com/schemas/2009/05/TcModuleClass" Hash="dabc39a6-d6e9-40e1-9c93-fcf8ea197b68" GeneratedBy="TwinCAT XAE Plc">
  <DataTypes>
  </DataTypes>
  <Modules>
    <Module GUID="b49a2cc8-94ed-4106-b26c-5e7d9aaa9b8a" TcSmClass="TComPlcObjDef">
      <DataAreas>
        <DataArea>
          <AreaNo AreaType="Standard">0</AreaNo>
'''

# %%
middle='''          <Symbol>
            <Name>.{}</Name>
            <BitSize>648</BitSize>
            <Type>STRING(80)</Type>
            <Properties>
              <Property>
                <Name>OPC.UA.DA</Name>
                <Value>1</Value>
              </Property>
              <Property>
                <Name>OPC.UA.DA.Access</Name>
                <Value>3</Value>
              </Property>
              <Property>
                <Name>OPC.UA.DA.Alias</Name>
                <Value>{}</Value>
              </Property>
            </Properties>
          </Symbol>
'''

# %%
end='''        </DataArea>
      </DataAreas>
    </Module>
  </Modules>
</TcModuleClass>
'''

# %%
with open("subor.tmc","w") as fw:
    fw.write(begin)
    i=0
    for pr in premenne:
        fw.write(middle.format(pr,pr))
    fw.write(end)
